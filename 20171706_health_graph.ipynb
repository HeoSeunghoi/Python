# %%
# %matplotlib nbagg
import numpy as np
import matplotlib.pyplot as plt
with plt.xkcd():
    plt.xlabel("time\n\"Stove Ownership\" from xkcd by Randall Monroe")
    plt.ylabel("my overall health")
    plt.plot([3,3], color = "w")
    plt.plot([2,2,2,0])
    plt.annotate('THE DAY I REALIZED\nI COULD COOK BACON\nWHENEVER I WANTED', xy = (2, 2), xytext = (0.2, 0.45), xycoords = 'data', textcoords = 'axes fraction', fontsize=12, arrowprops=dict(arrowstyle = "->", linewidth=1))

plt.xticks([])
plt.yticks([])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Out:
# <img src="data:image/png;base64,..." width="640">
